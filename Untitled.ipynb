# %%
import urllib3
from bs4 import BeautifulSoup
import html5lib
import re

stoop = "Малафеева Я одно время готовила только на чугунных сковородках, но есть у них один большой минус, их очень сложно вымыть , а потом перестала воевать с чугунными сковородками, и купила себе немецкую от BAF, пусть и не дешевая, зато никакой мороки не в использовании, ни в уходе. Пища не пригорает, сковорода не жирная, отлично моется в посудомойке и выглядит прилично.\
Игорь Титов сегодня купил сковородку с гранитовым покрытием , таском , аллюминевая , на дне накладка из магнитного материала , так что индукционку видит запросто , тефаль полно моделей видящих индукционку , и керамика и титан покрытие . Так что автор не вводите народ в заблуждение.ya-page_js_yes .ya-site-form_inited_no { display: none; }(function(w,d,c){var s=d.createElement('script'),h=d.getElementsByTagName('script')[0],e=d.documentElement;if((' '+e.className+' ').indexOf(' ya-page_js_yes ')===-1){e.className+=' ya-page_js_yes';}s.type='text/javascript';s.async=true;s.charset='utf-8';s.src=(d.location.protocol==='https:'?'https:':'http:')+'//site.yandex.net/v2.0/js/all.js';h.parentNode.insertBefore(s,h);(w[c]||(w[c]=[])).push(function(){Ya.Site.Form."
validtext = re.split(r'\.', stoop)
pattern5 = re.compile(r'[а-я]+')
group = ""
for peace in validtext:
    testvalid = pattern5.findall(peace)
    print(testvalid)
    if len(testvalid)>1:
        group = group + peace + '.'
print(group)
# Out:
# ['алафеева', 'одно', 'время', 'готовила', 'только', 'на', 'чугунных', 'сковородках', 'но', 'есть', 'у', 'них', 'один', 'большой', 'минус', 'их', 'очень', 'сложно', 'вымыть', 'а', 'потом', 'перестала', 'воевать', 'с', 'чугунными', 'сковородками', 'и', 'купила', 'себе', 'немецкую', 'от', 'пусть', 'и', 'не', 'дешевая', 'зато', 'никакой', 'мороки', 'не', 'в', 'использовании', 'ни', 'в', 'уходе']
# ['ища', 'не', 'пригорает', 'сковорода', 'не', 'жирная', 'отлично', 'моется', 'в', 'посудомойке', 'и', 'выглядит', 'прилично']
# ['горь', 'итов', 'сегодня', 'купил', 'сковородку', 'с', 'гранитовым', 'покрытием', 'таском', 'аллюминевая', 'на', 'дне', 'накладка', 'из', 'магнитного', 'материала', 'так', 'что', 'индукционку', 'видит', 'запросто', 'тефаль', 'полно', 'моделей', 'видящих', 'индукционку', 'и', 'керамика', 'и', 'титан', 'покрытие']
# ['ак', 'что', 'автор', 'не', 'вводите', 'народ', 'в', 'заблуждение']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...
